# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text,5)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
num_words = len(set(words))
from collections import Counter

word_counts = Counter(int_words)

# %%
thresh = 1e-5

total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}

p_drop = {word: 1 - np.sqrt(thresh/freqs[word]) for word in word_counts}

# %%
import random
## Your code here
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
tf.nn.sampled_softmax_loss?

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab, n_embedding), stddev=0.01), 
                            dtype=tf.float32)
    softmax_b = tf.Variable(tf.zeros(shape=n_vocab), 
                            dtype=tf.float32)
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(weights=softmax_w, biases=softmax_b, 
                                      labels=labels, inputs=embed,
                                      num_sampled=n_sampled, num_classes=n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.3946 0.0374 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.2978 0.0354 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.1478 0.0322 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.2560 0.0356 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.0694 0.0347 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.9964 0.0336 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 4.8959 0.0347 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 4.8694 0.0335 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.7516 0.0353 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 4.7853 0.0351 sec/batch
# Nearest to who: returning, achieved, odds, ins, irritability, incisive, innings, lithuanian,
# Nearest to known: bronx, attract, anastasius, enforced, examiners, receiver, town, nazi,
# Nearest to are: magazines, hemorrhages, filmfare, involved, train, holder, blockage, dynamo,
# Nearest to time: price, arr, generosity, prefers, containers, favorable, preferences, birthplace,
# Nearest to not: polluted, migration, speculated, pin, offices, zephaniah, celebration, transit,
# Nearest to in: president, main, faltered, sit, fringed, sig, class, merciless,
# Nearest to a: stauber, must, bulge, ropes, suggest, expelled, voles, mission,
# Nearest to used: segment, goth, gladly, reconciliation, distanced, cowl, quorum, articulated,
# Nearest to issue: reactors, billion, dickens, estimate, battlefield, ohr, without, banking,
# Nearest to mathematics: chronicle, prizes, oppenheimer, technologies, yankees, regimental, recruits, fourteen,
# Nearest to pope: robe, toughened, benedict, bagpipe, chron, ann, myelin, lds,
# Nearest to professional: investigate, bred, relegate, technology, niels, disappointment, forty, hippocrates,
# Nearest to animals: depth, refusing, alkoxide, automation, require, inaugurating, nebula, traits,
# Nearest to units: dylan, survive, artemis, swarms, gritty, bmw, ladislaus, bodies,
# Nearest to engine: beagle, inclination, drinker, mcneil, converts, glaad, troublesome, rigid,
# Nearest to taking: smitten, compositions, patent, frets, edition, paved, unpopularity, eavesdropping,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.8072 0.0324 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 4.7434 0.0307 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 4.7176 0.0317 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.7211 0.0320 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.7200 0.0352 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.7050 0.0354 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.6919 0.0354 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.7151 0.0343 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.6741 0.0327 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.7167 0.0342 sec/batch
# Nearest to who: returning, overbending, ins, vogt, bettina, irritability, sacerdotal, odds,
# Nearest to known: bronx, attract, reworked, electric, categorize, mediated, limnic, perpetuated,
# Nearest to are: hemorrhages, poaceae, vowel, blockage, filmfare, magazines, shotguns, superset,
# Nearest to time: arr, generosity, wanderers, assemblee, waking, gradient, greet, palate,
# Nearest to not: polluted, skins, zephaniah, speculated, digs, mixes, subsets, professing,
# Nearest to in: faltered, calf, buffet, fringed, main, abkhaz, sit, class,
# Nearest to a: stauber, hitz, voles, croquet, suggest, puppets, ophthalmology, must,
# Nearest to used: goth, articulated, gladly, exist, disbandment, numerals, segment, cowl,
# Nearest to issue: ohr, fumimaro, stwertka, cures, entrenched, dickens, rcr, kroner,
# Nearest to mathematics: glaad, episteme, oppenheimer, barbarous, fourteen, prizes, technologies, forecasting,
# Nearest to pope: robe, toughened, emperor, benedict, lds, chron, emeritus, wolfman,
# Nearest to professional: investigate, bred, relegate, fromme, matron, schiff, niels, brooklyn,
# Nearest to animals: depth, alkoxide, automation, inaugurating, require, luca, diversion, entrenched,
# Nearest to units: swarms, survive, ladislaus, gritty, sacrificing, ceawlin, meddle, arrestor,
# Nearest to engine: glaad, troublesome, mcneil, drinker, lancastrian, mammalian, inclination, games,
# Nearest to taking: smitten, username, unpopularity, affectation, compositions, stagnant, frets, stoppages,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.6248 0.0358 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.6142 0.0354 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6407 0.0356 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6271 0.0357 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.5801 0.0353 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6261 0.0322 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.5660 0.0337 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.5891 0.0313 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.5703 0.0333 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6266 0.0337 sec/batch
# Nearest to who: returning, odds, overbending, sacerdotal, everly, mayen, irritability, incisive,
# Nearest to known: consorts, bronx, reworked, limnic, attract, ibenik, categorize, anastasius,
# Nearest to are: hemorrhages, blockage, dynamo, vowel, poaceae, rl, nul, sandworm,
# Nearest to time: xers, arr, waking, hsls, generosity, greet, fremont, birthplace,
# Nearest to not: professing, zephaniah, skins, speculated, historians, digs, polluted, proverbs,
# Nearest to in: abkhaz, calf, buffet, psr, fringed, main, freyr, class,
# Nearest to a: jest, elcano, cournot, hitz, stauber, mingus, berghouata, sarnia,
# Nearest to used: gladly, cliffordadams, goth, etch, multimedia, test, numerals, articulated,
# Nearest to issue: fumimaro, kroner, ohr, abjuration, corporatocracy, assurances, stwertka, junnin,
# Nearest to mathematics: episteme, prizes, oppenheimer, glaad, barbarous, chronicle, mindy, deserters,
# Nearest to pope: benedict, nicaea, robe, emperor, caesarea, bishops, toughened, dummies,
# Nearest to professional: investigate, bred, brooklyn, niels, relegate, schiff, matron, erewhon,
# Nearest to animals: inaugurating, depth, encoders, alkoxide, entrenched, diversion, automation, require,
# Nearest to units: survive, ladislaus, meddle, brooklyn, ceawlin, fifths, unbound, swarms,
# Nearest to engine: drinker, glaad, mcneil, busiest, games, lancastrian, programmable, neutron,
# Nearest to taking: smitten, unpopularity, username, affectation, stoppages, reusability, gravesite, beli,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.5836 0.0337 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5876 0.0325 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5571 0.0337 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5331 0.0338 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5109 0.0354 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.4756 0.0355 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6455 0.0352 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6062 0.0308 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5251 0.0352 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5008 0.0353 sec/batch
# Nearest to who: returning, odds, ins, sacerdotal, kosar, overbending, nit, medved,
# Nearest to known: consorts, reworked, bronx, limnic, perpetuated, anastasius, tribute, examiners,
# Nearest to are: hemorrhages, vowel, dynamo, nul, rl, kendrick, sahelian, blockage,
# Nearest to time: arr, xers, hsls, lees, birthplace, assemblee, generosity, apologies,
# Nearest to not: professing, zephaniah, speculated, digs, paced, polluted, resonators, skins,
# Nearest to in: fringed, psr, class, main, ryukyuans, abkhaz, incarcerated, maidens,
# Nearest to a: kowtow, elcano, mobiles, cournot, landis, jest, radiator, hobbled,
# Nearest to used: cliffordadams, numerals, goth, gladly, sickle, departmental, articulated, multimedia,
# Nearest to issue: kroner, fumimaro, ohr, fbi, assurances, rcr, abjuration, stwertka,
# Nearest to mathematics: prizes, episteme, glaad, oppenheimer, foundational, mindy, barbarous, chronicle,
# Nearest to pope: benedict, nicaea, robe, caesarea, emperor, toughened, ecumenical, rightly,
# Nearest to professional: investigate, bred, card, brooklyn, relegate, schiff, niels, matron,
# Nearest to animals: inaugurating, encoders, depth, peculiarity, monkey, traits, entrenched, naoh,
# Nearest to units: survive, clk, brooklyn, meddle, mass, unbound, bodies, unspecified,
# Nearest to engine: mcneil, busiest, drinker, armament, motors, glaad, carbine, diesel,
# Nearest to taking: smitten, username, unpopularity, affectation, reiterates, eyebrow, overdubbed, ptl,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4889 0.0330 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.5064 0.0353 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.4433 0.0325 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4680 0.0342 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4572 0.0324 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4963 0.0333 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.4209 0.0258 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.3676 0.0336 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.3193 0.0330 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.3417 0.0355 sec/batch
# Nearest to who: returning, odds, kosar, ins, achieved, sacerdotal, nit, husayn,
# Nearest to known: consorts, reworked, anastasius, bronx, tribute, limnic, perpetuated, examiners,
# Nearest to are: rl, hemorrhages, nul, bhishma, dynamo, vowel, blockage, preceding,
# Nearest to time: arr, xers, hsls, lees, fremont, generosity, guthrum, assemblee,
# Nearest to not: digs, carps, speculated, professing, polluted, paced, proverbs, ana,
# Nearest to in: psr, incarcerated, main, barrie, ryukyuans, class, rambouillet, ratsiraka,
# Nearest to a: kowtow, elcano, mobiles, cournot, horseshoes, croquet, stauber, repressor,
# Nearest to used: cliffordadams, numerals, gladly, departmental, pejorative, kavina, sickle, variants,
# Nearest to issue: kroner, fumimaro, fbi, ohr, without, abjuration, assurances, corporatocracy,
# Nearest to mathematics: prizes, glaad, episteme, oppenheimer, foundational, chronicle, alumnus, trivial,
# Nearest to pope: benedict, nicaea, caesarea, emperor, robe, toughened, ii, rightly,
# Nearest to professional: investigate, bred, card, technology, brooklyn, relegate, kodokan, erewhon,
# Nearest to animals: inaugurating, encoders, nebula, traits, peculiarity, depth, vegetables, monkey,
# Nearest to units: survive, fifths, reconnaissance, mass, unspecified, benchmarking, emitting, arrestor,
# Nearest to engine: aircraft, drinker, armament, powered, engines, programmable, mcneil, motors,
# Nearest to taking: smitten, unpopularity, username, affectation, cheating, eyebrow, alekhine, ptl,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.2891 0.0368 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.3429 0.0340 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.2699 0.0354 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.3727 0.0355 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.2920 0.0352 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.3339 0.0339 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.3229 0.0338 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.2365 0.0329 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.2236 0.0339 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.2386 0.0339 sec/batch
# Nearest to who: returning, kosar, ins, odds, nit, bornemisza, skill, overbending,
# Nearest to known: reworked, bronx, nitrogenous, poisson, tribute, limnic, consorts, perpetuated,
# Nearest to are: parishes, hemorrhages, huntingdon, rl, bhishma, nul, molecules, blockage,
# Nearest to time: xers, cammag, generosity, wanderers, arr, fremont, foregoing, lees,
# Nearest to not: carps, mixes, proverbs, speculated, digs, paced, legitimized, resonators,
# Nearest to in: main, incarcerated, psr, emission, ryukyuans, websphere, isotope, fringed,
# Nearest to a: kowtow, mobiles, stauber, bust, cournot, repressor, radiator, rhinoceroses,
# Nearest to used: numerals, departmental, pejorative, etch, articulated, sickle, common, cliffordadams,
# Nearest to issue: kroner, assurances, fumimaro, entrenched, fbi, avoiding, gnp, shuffling,
# Nearest to mathematics: prizes, glaad, episteme, foundational, oppenheimer, technologies, chronicle, mathematicians,
# Nearest to pope: benedict, nicaea, caesarea, emperor, excommunication, toughened, robe, jehoshaphat,
# Nearest to professional: investigate, bred, card, moise, brooklyn, technology, kodokan, waddell,
# Nearest to animals: inaugurating, vegetables, nebula, monkey, reptiles, entrenched, traits, luca,
# Nearest to units: reconnaissance, survive, fifths, unspecified, benchmarking, armoured, emitting, unbound,
# Nearest to engine: drinker, armament, programmable, mcneil, engines, glaad, lancastrian, powered,
# Nearest to taking: smitten, unpopularity, username, stoppages, affectation, eavesdropping, cheating, reiterates,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.2241 0.0338 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.2992 0.0352 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.2717 0.0352 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.2830 0.0332 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.2930 0.0331 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.3315 0.0354 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.2503 0.0348 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.2364 0.0335 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3138 0.0330 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.2822 0.0353 sec/batch
# Nearest to who: returning, overbending, ins, skill, nit, odds, bornemisza, ascetic,
# Nearest to known: tribute, consorts, reworked, nitrogenous, bronx, cartagena, lambda, poisson,
# Nearest to are: parishes, nul, poaceae, rl, instantaneous, molecules, hemorrhages, dt,
# Nearest to time: arr, generosity, xers, cammag, waking, fremont, gorski, arp,
# Nearest to not: proverbs, legitimized, carps, digs, implicitly, catullus, speculated, disputing,
# Nearest to in: eris, faltered, main, fringed, ztt, circus, incarcerated, afp,
# Nearest to a: kowtow, flavianum, stauber, mobiles, legitimate, elcano, cournot, reichsf,
# Nearest to used: articulated, pejorative, multimedia, sickle, numerals, libro, etch, gladly,
# Nearest to issue: fumimaro, kroner, fbi, assurances, reactors, abjuration, entrenched, avoiding,
# Nearest to mathematics: prizes, technologies, episteme, university, chronicle, oppenheimer, modeling, combinatorial,
# Nearest to pope: benedict, nicaea, caesarea, emperor, antonius, toughened, xii, excommunication,
# Nearest to professional: investigate, bred, technology, card, waddell, moise, brooklyn, schiff,
# Nearest to animals: inaugurating, reptiles, traits, nebula, monkey, vegetables, species, entrenched,
# Nearest to units: reconnaissance, fifths, metre, unspecified, armoured, benchmarking, emitting, survive,
# Nearest to engine: lancastrian, drinker, engines, mcneil, stroke, glaad, armament, keyser,
# Nearest to taking: smitten, unpopularity, stoppages, username, affectation, cheating, excommunication, imposes,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.2714 0.0332 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.2578 0.0317 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.2604 0.0355 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.2279 0.0332 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3018 0.0335 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.2512 0.0355 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.2907 0.0316 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.2619 0.0339 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.2257 0.0349 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.2694 0.0348 sec/batch
# Nearest to who: returning, skill, ascetic, nit, bornemisza, quantitative, overbending, westerner,
# Nearest to known: consorts, bronx, excavators, tribute, poisson, cartagena, workable, perpetuated,
# Nearest to are: parishes, nul, rl, hemorrhages, gwangju, sahelian, instantaneous, mistakes,
# Nearest to time: generosity, arr, gorski, foregoing, creed, assuage, samurai, preemptive,
# Nearest to not: proverbs, carps, legitimized, implicitly, speculated, bash, digs, ana,
# Nearest to in: as, fringed, main, abkhaz, sig, uranian, accorded, ratsiraka,
# Nearest to a: kowtow, mobiles, elcano, shadowing, flavianum, stauber, legitimate, copula,
# Nearest to used: goth, libro, numerals, articulated, pejorative, common, aspectual, multimedia,
# Nearest to issue: fumimaro, assurances, s, kroner, stwertka, fbi, avoiding, reactors,
# Nearest to mathematics: chronicle, technologies, episteme, prizes, scania, salary, fourteen, barbarous,
# Nearest to pope: benedict, nicaea, caesarea, bishops, excommunication, emperor, antonius, toughened,
# Nearest to professional: investigate, technology, bred, card, kodokan, moise, brooklyn, sponsorship,
# Nearest to animals: inaugurating, reptiles, traits, monkey, nebula, luca, birds, peculiarity,
# Nearest to units: reconnaissance, infantry, armoured, fifths, clk, survive, unspecified, processors,
# Nearest to engine: engines, stroke, combustion, diesel, ignition, mcneil, airspeed, armament,
# Nearest to taking: unpopularity, smitten, frets, stoppages, affectation, username, eyebrow, eavesdropping,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.2626 0.0334 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2273 0.0324 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3288 0.0346 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.2745 0.0321 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.2884 0.0313 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.1998 0.0345 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.1742 0.0311 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2827 0.0347 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1573 0.0341 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2079 0.0356 sec/batch
# Nearest to who: returning, westerner, ascetic, bornemisza, overbending, ins, skill, odds,
# Nearest to known: consorts, cypress, tribute, poisson, excavators, cartagena, wiesner, workable,
# Nearest to are: parishes, nul, hemorrhages, train, mistakes, rl, enola, gwangju,
# Nearest to time: generosity, arr, guthrum, gorski, samurai, but, birthplace, apologies,
# Nearest to not: speculated, carps, ana, proverbs, digs, pwn, paced, legitimized,
# Nearest to in: vacation, as, incarcerated, bryozoans, fringed, venlo, tis, ryukyuans,
# Nearest to a: mobiles, repressor, elcano, stauber, halfwidth, scaling, disclaimed, nonterminal,
# Nearest to used: articulated, goth, cls, etch, bluish, multimedia, pejorative, tarmac,
# Nearest to issue: fumimaro, kroner, s, assurances, fbi, stwertka, avoiding, entrenched,
# Nearest to mathematics: technologies, mathematicians, episteme, prizes, chronicle, ciphers, theorem, colones,
# Nearest to pope: benedict, nicaea, xii, caesarea, emperor, ii, huguenots, excommunication,
# Nearest to professional: brooklyn, investigate, waddell, kodokan, moise, technology, greene, warwick,
# Nearest to animals: nebula, inaugurating, reptiles, monkey, spiders, traits, luca, birds,
# Nearest to units: reconnaissance, metre, unspecified, fifths, infantry, unit, meddle, nist,
# Nearest to engine: engines, diesel, combustion, cylinder, stroke, ignition, airspeed, drinker,
# Nearest to taking: smitten, unpopularity, affectation, username, frets, stoppages, eyebrow, eavesdropping,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2361 0.0337 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2181 0.0325 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.2684 0.0180 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.1904 0.0317 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1453 0.0336 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1561 0.0347 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1143 0.0356 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1684 0.0353 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1395 0.0341 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1102 0.0325 sec/batch
# Nearest to who: returning, westerner, ascetic, ins, overbending, skill, odds, nit,
# Nearest to known: bronx, consorts, excavators, chadwick, cartagena, cypress, nitrogenous, poisson,
# Nearest to are: train, nul, hemorrhages, parishes, rl, sahelian, fielders, enola,
# Nearest to time: generosity, gorski, arr, fremont, guthrum, antares, assuage, but,
# Nearest to not: speculated, carps, paced, mixes, apart, prisma, legitimized, celebration,
# Nearest to in: vacation, bryozoans, sig, incarcerated, cur, as, studied, fringed,
# Nearest to a: elcano, mobiles, ajax, eukaryotes, scaling, hotter, beirut, hobbled,
# Nearest to used: articulated, tarmac, pejorative, sickle, cae, goth, nitrite, cls,
# Nearest to issue: fumimaro, assurances, kroner, avoiding, stwertka, essences, arminianism, entrenched,
# Nearest to mathematics: mathematicians, technologies, episteme, prizes, chronicle, theorem, colones, ciphers,
# Nearest to pope: benedict, nicaea, xii, excommunication, caesarea, emperor, lengths, huguenots,
# Nearest to professional: waddell, brooklyn, technology, kodokan, investigate, moise, bred, afl,
# Nearest to animals: vegetarianism, nebula, mayhem, alligators, luca, shinto, vegetables, evolution,
# Nearest to units: reconnaissance, infantry, processors, armoured, clk, unit, wc, density,
# Nearest to engine: engines, diesel, cylinder, stroke, airspeed, mcneil, keyser, powered,
# Nearest to taking: affectation, smitten, stoppages, unpopularity, username, eyebrow, cheating, ptl,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2205 0.0366 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1506 0.0352 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1488 0.0341 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.0697 0.0338 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1325 0.0308 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.0947 0.0310 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.0761 0.0339 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1109 0.0353 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1461 0.0353 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1061 0.0354 sec/batch
# Nearest to who: returning, kosar, ascetic, honorific, westerner, ins, overbending, nit,
# Nearest to known: bronx, nitrogenous, chadwick, consorts, poisson, cypress, excavators, alcoholic,
# Nearest to are: parishes, nul, poaceae, train, possess, respective, buff, albinism,
# Nearest to time: generosity, arr, gorski, wanderers, werther, slugged, preemptive, but,
# Nearest to not: speculated, carps, zephaniah, celebration, digs, legitimized, paced, helpful,
# Nearest to in: vacation, barristers, bandy, cur, myles, incarcerated, as, evangelicals,
# Nearest to a: elcano, mobiles, radiator, croquet, shadowing, scaling, bust, stauber,
# Nearest to used: articulated, bluish, pejorative, common, cae, sickle, etch, gladly,
# Nearest to issue: kroner, assurances, fumimaro, avoiding, reactors, stwertka, entrenched, ortho,
# Nearest to mathematics: mathematicians, technologies, prizes, episteme, erd, chronicle, theorem, muff,
# Nearest to pope: nicaea, benedict, excommunication, xii, emperor, bishops, papacy, synod,
# Nearest to professional: card, brooklyn, waddell, investigate, moise, kodokan, bred, technology,
# Nearest to animals: alligators, eat, monkey, vegetarianism, amniotes, nebula, mayhem, reptiles,
# Nearest to units: reconnaissance, processors, infantry, nist, armoured, unit, density, acid,
# Nearest to engine: engines, cylinder, diesel, hammerhead, airspeed, stroke, flaws, armament,
# Nearest to taking: stoppages, frets, unpopularity, eyebrow, smitten, cheating, imposes, affectation,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1566 0.0327 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2304 0.0353 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1773 0.0353 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.0665 0.0351 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1502 0.0353 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1100 0.0329 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1904 0.0353 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1352 0.0341 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1063 0.0319 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1915 0.0352 sec/batch
# Nearest to who: returning, kosar, ascetic, westerner, skill, overbending, ins, dimensionally,
# Nearest to known: excavators, consorts, cypress, poisson, transferring, chadwick, bronx, canopus,
# Nearest to are: nul, possess, parishes, albinism, tonle, poaceae, morphisms, malays,
# Nearest to time: xers, gorski, arr, preemptive, generosity, but, arp, wanderers,
# Nearest to not: speculated, celebration, zephaniah, hunnish, digs, yves, legitimized, still,
# Nearest to in: vacation, as, top, prescott, circus, shown, barristers, bonn,
# Nearest to a: mobiles, elcano, radiator, hotter, scaling, discriminant, eukaryotes, gonorrhea,
# Nearest to used: articulated, sickle, common, cliffordadams, variants, pejorative, bluish, mcnally,
# Nearest to issue: assurances, avoiding, presley, reactors, stwertka, fumimaro, pathophysiology, essences,
# Nearest to mathematics: mathematicians, episteme, technologies, prizes, erd, combinatorial, diophantine, theorem,
# Nearest to pope: benedict, excommunication, nicaea, xii, antonius, synod, papacy, lengths,
# Nearest to professional: brooklyn, waddell, kodokan, technology, graduate, card, moise, cyrillic,
# Nearest to animals: alligators, amniotes, inaugurating, monkey, mayhem, nebula, spiders, eat,
# Nearest to units: reconnaissance, infantry, unit, armoured, processors, acid, nist, brigadier,
# Nearest to engine: engines, stroke, hammerhead, mcneil, flaws, keyser, splintering, drinker,
# Nearest to taking: stoppages, unpopularity, eyebrow, smitten, corleone, unconquered, affectation, excommunication,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1879 0.0341 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1418 0.0353 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1172 0.0351 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1416 0.0327 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1452 0.0342 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1169 0.0329 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1631 0.0353 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1083 0.0354 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1888 0.0330 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2038 0.0330 sec/batch
# Nearest to who: returning, kosar, ascetic, westerner, havoc, medved, hata, warns,
# Nearest to known: consorts, excavators, anastasius, bronx, transferring, poisson, wiesner, iudex,
# Nearest to are: nul, parishes, morphisms, gag, phodopus, kendrick, mistakes, respective,
# Nearest to time: xers, tojo, but, gorski, wanderers, cammag, guthrum, generosity,
# Nearest to not: zephaniah, speculated, proverbs, this, celebration, legitimized, hunnish, percentile,
# Nearest to in: as, vacation, bryozoans, tojo, cavour, circus, filing, demands,
# Nearest to a: mobiles, disclaimed, elcano, scaling, death, echols, jacurutu, croquet,
# Nearest to used: articulated, sickle, pejorative, common, cliffordadams, variants, goth, cae,
# Nearest to issue: fumimaro, assurances, avoiding, reactors, stwertka, s, oblique, kroner,
# Nearest to mathematics: prizes, mathematicians, technologies, episteme, erd, university, chronicle, zwicky,
# Nearest to pope: benedict, excommunication, nicaea, xii, bishops, antonius, aegeas, synod,
# Nearest to professional: brooklyn, kodokan, moise, bred, waddell, situations, goetz, technology,
# Nearest to animals: alligators, amniotes, monkey, shinto, nebula, entheogens, inaugurating, mayhem,
# Nearest to units: reconnaissance, infantry, unit, armoured, counties, processors, brigadier, metre,
# Nearest to engine: engines, combustion, stroke, mcneil, ramjet, ignition, turbojet, diesel,
# Nearest to taking: unpopularity, eyebrow, ptl, smitten, stoppages, affectation, corleone, abandon,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1811 0.0317 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1350 0.0330 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0871 0.0309 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1267 0.0351 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0114 0.0354 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1831 0.0354 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1200 0.0351 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1300 0.0350 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1897 0.0097 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0933 0.0329 sec/batch
# Nearest to who: kosar, returning, westerner, quantitative, ascetic, nehru, havoc, ins,
# Nearest to known: consorts, taggart, canopus, cypress, excavators, vitis, frigates, transferring,
# Nearest to are: tonle, nul, phodopus, kendrick, albinism, gag, keeshond, parishes,
# Nearest to time: xers, cammag, but, guthrum, tojo, wanderers, ire, endures,
# Nearest to not: speculated, this, legitimized, zephaniah, percentile, celebration, proverbs, prohibitive,
# Nearest to in: as, circus, shown, bryozoans, karachi, tojo, bandy, ryukyuans,
# Nearest to a: elcano, kowtow, mobiles, scaling, msf, expelled, distinguished, beirut,
# Nearest to used: articulated, sickle, variants, common, bluish, pejorative, cae, cliffordadams,
# Nearest to issue: avoiding, assurances, oblique, katal, fumimaro, stwertka, kroner, reactors,
# Nearest to mathematics: mathematicians, prizes, erd, episteme, zwicky, bening, technologies, university,
# Nearest to pope: benedict, xii, excommunication, nicaea, digestive, consecrated, naples, toni,
# Nearest to professional: kodokan, technology, card, situations, waddell, graduate, bred, luton,
# Nearest to animals: shinto, alligators, animal, entheogens, amniotes, foretelling, inaugurating, spiders,
# Nearest to units: reconnaissance, unit, metre, infantry, si, counties, brigadier, density,
# Nearest to engine: engines, stroke, combustion, ignition, mcneil, lamborghini, keyser, turbojet,
# Nearest to taking: luton, eyebrow, stoppages, absent, affectation, ptl, abandon, kilometer,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0496 0.0350 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0447 0.0346 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0716 0.0341 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0347 0.0337 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0678 0.0309 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0481 0.0324 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0985 0.0338 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0628 0.0353 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1037 0.0328 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0156 0.0317 sec/batch
# Nearest to who: kosar, returning, westerner, skill, quantitative, nehru, ascetic, warns,
# Nearest to known: excavators, poisson, bronx, transferring, canopus, consorts, frigates, taggart,
# Nearest to are: respective, synapomorphies, morphisms, phodopus, possess, kendrick, molecules, of,
# Nearest to time: cammag, but, xers, slugged, weightlessness, preemptive, ever, arr,
# Nearest to not: this, proverbs, speculated, celebration, paced, pham, osteoclasts, plh,
# Nearest to in: bryozoans, as, shown, gaud, the, polic, litani, top,
# Nearest to a: kowtow, scaling, msf, beirut, expelled, obiang, elcano, distinguished,
# Nearest to used: be, articulated, cae, common, sickle, variants, fewer, cliffordadams,
# Nearest to issue: assurances, stwertka, avoiding, kroner, reactors, fumimaro, s, katal,
# Nearest to mathematics: mathematicians, erd, prizes, episteme, technologies, bening, university, theorem,
# Nearest to pope: benedict, excommunication, xii, papacy, nicaea, bishops, synod, digestive,
# Nearest to professional: kodokan, moise, bred, practitioners, accountants, situations, luton, afl,
# Nearest to animals: alligators, shinto, inaugurating, luca, mayhem, foretelling, human, clutch,
# Nearest to units: reconnaissance, unit, brigadier, metre, infantry, battery, counties, millimetre,
# Nearest to engine: engines, stroke, combustion, keyser, mcneil, turbojet, ignition, lancastrian,
# Nearest to taking: luton, stoppages, frets, absent, affectation, cheating, excommunication, constipation,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0099 0.0339 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0568 0.0354 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0136 0.0334 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0384 0.0326 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0948 0.0355 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0482 0.0347 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0754 0.0326 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1634 0.0354 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0802 0.0336 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0521 0.0352 sec/batch
# Nearest to who: returning, kosar, westerner, skill, quantitative, allele, ascetic, nehru,
# Nearest to known: sweeter, excavators, vitis, transferring, bronx, frigates, canopus, alcoholic,
# Nearest to are: to, molecules, respective, all, monomers, synapomorphies, parishes, of,
# Nearest to time: cammag, xers, slugged, but, generosity, werther, pilgrimage, wanderers,
# Nearest to not: this, carthaginian, celebration, implicitly, does, do, speculated, hunnish,
# Nearest to in: bryozoans, shown, as, different, squealer, gaud, the, considered,
# Nearest to a: of, the, scaling, plancherel, any, cartoons, and, legitimacy,
# Nearest to used: articulated, be, sickle, common, pejorative, cae, variants, term,
# Nearest to issue: assurances, avoiding, oblique, stwertka, reactors, cetus, discordians, s,
# Nearest to mathematics: mathematicians, prizes, episteme, theorem, bening, chronicle, whitehead, zwicky,
# Nearest to pope: benedict, excommunication, papacy, xii, digestive, bishops, nicaea, antipope,
# Nearest to professional: accountants, kodokan, nomos, waddell, technology, graduate, practitioners, goetz,
# Nearest to animals: alligators, inaugurating, amniotes, luca, clutch, animal, fauna, shinto,
# Nearest to units: reconnaissance, unit, brigadier, metre, millimetre, density, processors, redefined,
# Nearest to engine: engines, stroke, combustion, ignition, cylinder, turbojet, ramjet, crankshaft,
# Nearest to taking: stoppages, imposes, cheating, luton, absent, frets, abandon, excommunication,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0492 0.0353 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0563 0.0331 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.1146 0.0342 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0739 0.0337 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0400 0.0319 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0956 0.0320 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1184 0.0345 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.1308 0.0348 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0732 0.0337 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0570 0.0354 sec/batch
# Nearest to who: returning, hata, quantitative, skill, medved, hagiography, honorific, westerner,
# Nearest to known: consorts, excavators, the, anastasius, transferring, indiction, homeomorphism, bronx,
# Nearest to are: parishes, certain, nul, all, oxidants, cnidarians, to, phodopus,
# Nearest to time: but, cammag, outline, pilgrimage, tierra, ever, preemptive, jizya,
# Nearest to not: this, hunnish, speculated, does, traditionalist, celebration, implicitly, carthaginian,
# Nearest to in: shown, to, as, bryozoans, the, gaud, ghent, six,
# Nearest to a: the, beirut, mobiles, to, elizabeth, of, msf, suggest,
# Nearest to used: be, articulated, common, sickle, pejorative, cae, usage, term,
# Nearest to issue: assurances, avoiding, stwertka, oblique, reactors, s, fumimaro, katal,
# Nearest to mathematics: mathematicians, prizes, theorem, episteme, chronicle, bening, fourteen, whitehead,
# Nearest to pope: excommunication, benedict, digestive, papacy, bishops, beiping, xii, toni,
# Nearest to professional: accountants, kodokan, nomos, waddell, oftentimes, validity, practitioners, bred,
# Nearest to animals: alligators, clutch, entheogens, human, inaugurating, animal, amniotes, shinto,
# Nearest to units: reconnaissance, unit, brigadier, metre, density, processors, millimetre, infantry,
# Nearest to engine: engines, stroke, turbojet, ignition, combustion, cylinder, powered, fighter,
# Nearest to taking: unconquered, excommunication, stoppages, affectation, frets, unpopularity, absent, abandon,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0910 0.0343 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0265 0.0352 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0520 0.0329 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.1331 0.0352 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0925 0.0338 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1789 0.0354 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1591 0.0345 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.1316 0.0306 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0436 0.0328 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0733 0.0333 sec/batch
# Nearest to who: returning, westerner, tuonela, medved, kosar, quantitative, hata, havoc,
# Nearest to known: consorts, laika, the, scientist, excavators, taggart, of, transferring,
# Nearest to are: all, nul, cnidarians, oxidants, alif, certain, parishes, solferino,
# Nearest to time: but, pilgrimage, generosity, hsls, samurai, outline, ever, at,
# Nearest to not: this, speculated, does, hunnish, implicitly, carnap, do, ranke,
# Nearest to in: to, as, the, shown, gaud, one, was, ghent,
# Nearest to a: dredd, the, of, to, s, and, mobiles, in,
# Nearest to used: common, be, sickle, articulated, bluish, usage, evolutionist, cae,
# Nearest to issue: avoiding, assurances, katal, stwertka, reactors, oblique, ferreira, amex,
# Nearest to mathematics: mathematicians, prizes, episteme, fourteen, bening, philosophische, zwicky, technologies,
# Nearest to pope: benedict, excommunication, papacy, naples, papal, bishops, nicaea, antipope,
# Nearest to professional: kodokan, accountants, validity, waddell, oftentimes, nomos, graduate, practitioners,
# Nearest to animals: shinto, koans, luca, inaugurating, foretelling, ghaznavid, human, alligators,
# Nearest to units: reconnaissance, unit, redefined, nist, metre, brigadier, infantry, millimetre,
# Nearest to engine: engines, stroke, turbojet, ignition, combustion, cylinder, powered, gearbox,
# Nearest to taking: seizures, frets, absent, unconquered, abandon, affectation, stoppages, scales,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9676 0.0329 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0714 0.0332 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0403 0.0348 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0725 0.0342 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0795 0.0306 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.1017 0.0311 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0606 0.0305 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9847 0.0338 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0233 0.0316 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0304 0.0315 sec/batch
# Nearest to who: tuonela, kosar, returning, esarhaddon, westerner, concubine, quantitative, hagiography,
# Nearest to known: the, of, excavators, consorts, laika, scientist, chadwick, first,
# Nearest to are: all, of, cnidarians, alif, possess, other, and, nul,
# Nearest to time: pilgrimage, but, slugged, dvi, years, ever, birthplace, seconds,
# Nearest to not: this, speculated, legitimized, waal, traditionalist, hunnish, still, lacy,
# Nearest to in: to, the, as, shown, is, was, a, of,
# Nearest to a: the, of, and, dredd, to, is, s, in,
# Nearest to used: be, common, sickle, term, cae, articulated, variants, evolutionist,
# Nearest to issue: oblique, avoiding, assurances, katal, fumimaro, completion, reactors, ferreira,
# Nearest to mathematics: prizes, mathematicians, philosophische, erd, bening, episteme, theorem, whitehead,
# Nearest to pope: benedict, excommunication, xii, consecrated, beiping, nicaea, papacy, antipope,
# Nearest to professional: accountants, kodokan, waddell, validity, warwick, oftentimes, technology, goetz,
# Nearest to animals: shinto, animal, luca, cliques, koans, entheogens, foretelling, human,
# Nearest to units: unit, reconnaissance, redefined, infantry, metre, millimetre, density, si,
# Nearest to engine: engines, combustion, cylinder, stroke, crankshaft, turbojet, gearbox, ramjet,
# Nearest to taking: illiterate, seizures, absent, frets, constipation, stoppages, excommunication, unconquered,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0234 0.0369 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9631 0.0354 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0320 0.0354 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0154 0.0354 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0315 0.0353 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0228 0.0353 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9677 0.0354 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9981 0.0325 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9848 0.0347 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9753 0.0354 sec/batch
# Nearest to who: kosar, skill, returning, honorific, westerner, tuonela, lepton, hagiography,
# Nearest to known: the, of, bronx, propan, excavators, scientist, laika, cellists,
# Nearest to are: of, and, all, other, to, a, with, alif,
# Nearest to time: slugged, but, dvi, seconds, tierra, ever, cammag, pilgrimage,
# Nearest to not: this, do, does, carps, lacy, any, rocking, quartz,
# Nearest to in: to, the, as, of, a, and, one, nlds,
# Nearest to a: the, of, is, and, to, s, in, or,
# Nearest to used: be, common, articulated, sickle, traditionally, term, generally, to,
# Nearest to issue: oblique, assurances, reactors, avoiding, kroner, katal, stwertka, completion,
# Nearest to mathematics: prizes, mathematicians, erd, philosophische, theorem, bening, episteme, arise,
# Nearest to pope: benedict, excommunication, xii, digestive, papacy, myelin, consecrated, saint,
# Nearest to professional: accountants, kodokan, moise, bred, practitioners, validity, oftentimes, cyrillic,
# Nearest to animals: animal, cliques, shinto, amniotes, foretelling, koans, human, entheogens,
# Nearest to units: unit, reconnaissance, redefined, millimetre, si, density, metre, nist,
# Nearest to engine: engines, cylinder, crankshaft, turbojet, combustion, gearbox, ignition, stroke,
# Nearest to taking: unconquered, illiterate, absent, frets, stoppages, excommunication, imposes, castles,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0363 0.0346 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9826 0.0353 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9860 0.0348 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0475 0.0345 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0635 0.0337 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 4.0132 0.0354 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0099 0.0324 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0006 0.0325 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0495 0.0353 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0761 0.0351 sec/batch
# Nearest to who: kosar, honorific, francophonie, christology, returning, skill, reacted, opanal,
# Nearest to known: the, excavators, scientist, propan, consorts, laika, historians, cellists,
# Nearest to are: all, of, other, to, monomers, a, those, parishes,
# Nearest to time: but, slugged, preemptive, tierra, pilgrimage, orff, jizya, dvi,
# Nearest to not: this, does, do, rather, only, rocking, carps, lacy,
# Nearest to in: to, the, as, shown, a, and, is, for,
# Nearest to a: the, of, is, to, and, s, dredd, in,
# Nearest to used: be, sickle, articulated, common, generally, unless, usage, term,
# Nearest to issue: avoiding, reactors, ferreira, oblique, stwertka, katal, assurances, branding,
# Nearest to mathematics: prizes, erd, mathematicians, philosophische, episteme, fourteen, bening, whitehead,
# Nearest to pope: excommunication, benedict, digestive, onesimus, novellae, sacramental, gordon, wilander,
# Nearest to professional: accountants, practitioners, kodokan, validity, oftentimes, certified, professions, moise,
# Nearest to animals: animal, cliques, foretelling, shinto, luca, clutch, amniotes, fauna,
# Nearest to units: unit, si, redefined, reconnaissance, millimetre, density, metre, nist,
# Nearest to engine: engines, combustion, crankshaft, ignition, gearbox, diesel, stroke, turbojet,
# Nearest to taking: seizures, stoppages, unconquered, excommunication, absent, few, illiterate, imposes,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0520 0.0345 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 4.0428 0.0345 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0480 0.0352 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0607 0.0353 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0552 0.0353 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0601 0.0354 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0180 0.0309 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 4.0336 0.0353 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0086 0.0353 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.1159 0.0334 sec/batch
# Nearest to who: kosar, hata, christology, skill, ascetic, garter, messageboard, tuonela,
# Nearest to known: the, excavators, consorts, auth, first, and, bronx, chadwick,
# Nearest to are: all, to, other, be, those, of, there, some,
# Nearest to time: tierra, cammag, but, years, xers, seconds, preemptive, pilgrimage,
# Nearest to not: this, only, does, do, lobbies, any, barriers, hunnish,
# Nearest to in: the, as, to, and, two, six, nine, of,
# Nearest to a: the, of, to, is, s, and, dredd, in,
# Nearest to used: be, usage, generally, sickle, common, some, term, cliffordadams,
# Nearest to issue: avoiding, reactors, oblique, ferreira, stwertka, kroner, s, assurances,
# Nearest to mathematics: prizes, mathematicians, erd, philosophische, episteme, whitehead, bening, mathematician,
# Nearest to pope: benedict, excommunication, gordon, onesimus, bishops, beiping, sacramental, prefect,
# Nearest to professional: accountants, kodokan, validity, moise, practitioners, goetz, certified, graduate,
# Nearest to animals: animal, shinto, cliques, entheogens, sugarcane, clutch, luca, koans,
# Nearest to units: unit, reconnaissance, si, millimetre, redefined, nist, metre, density,
# Nearest to engine: engines, combustion, facts, ignition, ramjet, cylinder, mcneil, crankshaft,
# ...
# Nearest to engine: engines, rim, combustion, ramjet, turbojet, powered, merited, conditioners,
# Nearest to taking: ensues, before, returning, disrepair, losing, in, after, tyrant,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.9742 0.0336 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.8846 0.0353 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.9397 0.0314 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8868 0.0332 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.9665 0.0311 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.9781 0.0354 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.9653 0.0353 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.9801 0.0351 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9818 0.0325 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 4.0287 0.0317 sec/batch
# Nearest to who: have, those, was, in, are, also, and, to,
# Nearest to known: the, also, and, of, in, s, most, from,
# Nearest to are: and, all, other, have, of, many, to, can,
# Nearest to time: at, same, seconds, when, before, spent, for, in,
# Nearest to not: that, this, does, it, to, but, is, if,
# Nearest to in: the, to, a, and, as, of, from, also,
# Nearest to a: of, the, in, is, to, also, and, as,
# Nearest to used: for, term, be, also, sometimes, usage, common, example,
# Nearest to issue: upsetting, this, strip, oblique, without, ferreira, formally, discordians,
# Nearest to mathematics: mathematicians, erd, mathematical, philosophische, del, mathematician, whitehead, peano,
# Nearest to pope: papal, benedict, xii, papacy, encyclical, yoannis, xxiii, excommunication,
# Nearest to professional: training, accountants, certified, certification, wrestler, nomos, procedures, professions,
# Nearest to animals: animal, science, shinto, zoology, snowball, fauna, diversion, beasts,
# Nearest to units: unit, residing, si, density, regiments, redefined, reconnaissance, millimetre,
# Nearest to engine: engines, rim, crankshaft, ckisch, cards, fuel, ramjet, bayard,
# Nearest to taking: to, in, few, wageningen, returning, introspective, take, decided,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.9534 0.0342 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.9987 0.0331 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.9478 0.0347 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.9959 0.0351 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 4.0207 0.0305 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 4.0061 0.0350 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.9625 0.0339 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.9769 0.0336 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 4.0115 0.0352 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 4.0202 0.0348 sec/batch
# Nearest to who: those, have, to, lepton, are, their, well, also,
# Nearest to known: the, of, and, also, first, in, to, s,
# Nearest to are: all, can, other, is, of, to, and, only,
# Nearest to time: seconds, period, became, to, same, years, at, the,
# Nearest to not: but, does, is, this, that, only, if, to,
# Nearest to in: the, and, to, a, of, one, as, s,
# Nearest to a: in, the, to, of, is, as, also, and,
# Nearest to used: be, for, to, sometimes, term, generally, considered, still,
# Nearest to issue: upsetting, oblique, this, ferreira, formally, without, strip, jourdain,
# Nearest to mathematics: mathematicians, erd, mathematician, philosophische, university, del, whitehead, mathematical,
# Nearest to pope: papacy, papal, benedict, encyclical, yoannis, excommunication, xxiii, legate,
# Nearest to professional: accountants, certified, training, certification, wrestler, professions, kodokan, moise,
# Nearest to animals: animal, osborn, science, shinto, zoology, entheogens, reals, taxon,
# Nearest to units: unit, residing, si, reconnaissance, density, cgs, measures, army,
# Nearest to engine: engines, cards, google, crankshaft, ramjet, rim, fuel, optimize,
# Nearest to taking: in, castles, wageningen, returning, decided, miracles, take, its,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.9837 0.0343 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 4.0105 0.0341 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.9975 0.0329 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.9624 0.0342 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 4.0859 0.0355 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.9586 0.0353 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 4.0897 0.0333 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 4.0184 0.0315 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 4.0299 0.0337 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.9161 0.0334 sec/batch
# Nearest to who: those, have, well, and, were, been, became, was,
# Nearest to known: of, the, and, s, to, also, as, in,
# Nearest to are: all, can, other, is, small, these, have, and,
# Nearest to time: seconds, at, spent, became, until, one, teach, continually,
# Nearest to not: does, that, if, an, but, only, is, can,
# Nearest to in: the, and, to, a, as, one, of, s,
# Nearest to a: the, in, of, is, to, an, and, as,
# Nearest to used: be, for, in, also, generally, as, common, term,
# Nearest to issue: oblique, upsetting, ferreira, jourdain, agreed, strip, murderous, completion,
# Nearest to mathematics: erd, mathematicians, university, mathematical, philosophische, prizes, whitehead, mathematician,
# Nearest to pope: papal, benedict, papacy, yoannis, encyclical, beiping, xxiii, legate,
# Nearest to professional: training, accountants, moise, wrestler, certified, practitioners, validity, professions,
# Nearest to animals: animal, osborn, shinto, zoology, science, entheogens, fasciculata, foretelling,
# Nearest to units: unit, si, residing, measures, nist, reconnaissance, cgs, bipm,
# Nearest to engine: engines, crankshaft, rim, ramjet, cylinder, pesce, turbojet, rotary,
# Nearest to taking: returning, in, ensues, take, these, reluctantly, castles, decided,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.9664 0.0351 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.9620 0.0322 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.9853 0.0322 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.9937 0.0354 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 4.0095 0.0349 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 4.0134 0.0344 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9690 0.0239 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.9962 0.0351 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.9385 0.0333 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 4.0317 0.0319 sec/batch
# Nearest to who: have, to, those, were, was, in, after, and,
# Nearest to known: of, the, and, s, from, also, to, in,
# Nearest to are: all, other, can, is, these, have, of, some,
# Nearest to time: seconds, the, at, same, spent, became, before, year,
# Nearest to not: that, is, it, if, this, an, to, only,
# Nearest to in: the, and, a, of, to, as, is, from,
# Nearest to a: the, of, to, in, and, is, an, s,
# Nearest to used: be, in, generally, sometimes, as, for, to, the,
# Nearest to issue: upsetting, ferreira, murderous, jourdain, oblique, strip, agreed, formally,
# Nearest to mathematics: mathematicians, mathematical, erd, studies, prizes, atiyah, armed, whitehead,
# Nearest to pope: papal, papacy, benedict, popes, xiii, encyclical, excommunication, clement,
# Nearest to professional: training, association, wrestler, certification, practitioners, moise, certified, professions,
# Nearest to animals: animal, shinto, humans, zoology, osborn, science, domestication, entheogens,
# Nearest to units: unit, si, residing, metre, measures, cgs, bipm, nist,
# Nearest to engine: engines, ramjet, crankshaft, turbojet, rim, stroke, rotary, search,
# Nearest to taking: returning, ensues, these, take, before, in, antoninianus, instructs,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.9278 0.0346 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.9981 0.0335 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.9014 0.0308 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.9641 0.0335 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 4.0014 0.0327 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 4.0095 0.0326 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.9864 0.0346 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.9065 0.0340 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.9295 0.0313 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.9283 0.0353 sec/batch
# Nearest to who: have, in, are, he, those, made, as, higher,
# Nearest to known: the, of, in, and, also, a, s, from,
# Nearest to are: other, have, all, can, be, a, some, is,
# Nearest to time: seconds, which, same, became, when, the, at, spent,
# Nearest to not: this, that, does, but, can, if, it, and,
# Nearest to in: and, the, a, as, of, to, also, for,
# Nearest to a: the, of, in, is, and, also, which, an,
# Nearest to used: be, term, also, for, in, sometimes, to, as,
# Nearest to issue: upsetting, oblique, agreed, stouffer, completion, murderous, issuing, discordians,
# Nearest to mathematics: mathematical, erd, mathematicians, whitehead, mathematician, graph, prizes, atiyah,
# Nearest to pope: papal, popes, benedict, excommunication, papacy, xiii, yoannis, xxiii,
# Nearest to professional: certification, training, moise, professions, nomos, aia, accountants, kodokan,
# Nearest to animals: animal, zoology, humans, fasciculata, shinto, science, fauna, entheogens,
# Nearest to units: unit, si, residing, reconnaissance, ounces, redefined, gallon, bipm,
# Nearest to engine: engines, ramjet, crankshaft, rim, turbojet, rotary, pesce, cylinder,
# Nearest to taking: returning, these, take, in, before, flunitrazepam, several, nyu,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.9087 0.0352 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.9738 0.0310 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.9444 0.0339 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.9621 0.0342 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.9823 0.0332 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 4.0867 0.0327 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.9660 0.0353 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.9658 0.0335 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.9792 0.0317 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.9612 0.0324 sec/batch
# Nearest to who: those, have, are, people, is, also, in, lepton,
# Nearest to known: the, of, and, also, most, to, in, first,
# Nearest to are: other, is, can, all, a, of, some, have,
# Nearest to time: seconds, to, which, same, the, when, became, before,
# Nearest to not: this, does, that, is, but, also, and, only,
# Nearest to in: the, a, and, of, as, to, one, also,
# Nearest to a: the, of, in, and, also, to, is, as,
# Nearest to used: to, be, term, in, example, as, generally, for,
# Nearest to issue: upsetting, agreed, established, issues, oblique, this, stouffer, completion,
# Nearest to mathematics: erd, mathematician, whitehead, mathematical, prizes, mathematicians, knotted, hersh,
# Nearest to pope: papal, papacy, benedict, popes, xxiii, encyclical, xiii, yoannis,
# Nearest to professional: certification, training, association, moise, accountants, aia, wrestler, practitioners,
# Nearest to animals: animal, zoology, science, humans, fauna, entice, snowball, fasciculata,
# Nearest to units: unit, si, redefined, nist, bipm, cgs, ounces, residing,
# Nearest to engine: engines, ramjet, crankshaft, cylinder, rotary, combustion, sickness, stroke,
# Nearest to taking: returning, losing, wageningen, nyu, ensues, return, career, stats,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9858 0.0366 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 4.0421 0.0354 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.9399 0.0351 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 4.0053 0.0353 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.9855 0.0345 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.9722 0.0351 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.9682 0.0340 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.9929 0.0331 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.9513 0.0322 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.9634 0.0350 sec/batch
# Nearest to who: have, those, are, an, of, all, that, were,
# Nearest to known: the, of, most, and, in, to, also, first,
# Nearest to are: all, is, to, as, some, can, and, of,
# Nearest to time: seconds, to, which, after, before, were, more, when,
# Nearest to not: this, that, does, is, only, but, to, if,
# Nearest to in: the, and, as, a, to, of, from, for,
# Nearest to a: the, and, in, of, to, is, also, an,
# Nearest to used: sometimes, in, term, be, common, some, generally, example,
# Nearest to issue: agreed, this, of, upsetting, when, established, the, do,
# Nearest to mathematics: mathematical, erd, mathematician, mathematicians, peano, whitehead, sulba, knotted,
# Nearest to pope: papal, popes, papacy, xxiii, benedict, xiii, encyclical, militum,
# Nearest to professional: certification, training, moise, accountants, kodokan, certified, aia, wrestler,
# Nearest to animals: animal, fauna, zoology, humans, entheogens, goodall, entice, invertebrate,
# Nearest to units: unit, redefined, cgs, si, ounces, residing, customary, brigadier,
# Nearest to engine: engines, crankshaft, ramjet, cylinder, ejector, combustion, stroke, efficient,
# Nearest to taking: losing, returning, return, wageningen, harpist, nyu, scales, decided,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 4.0165 0.0359 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.9564 0.0354 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 4.0564 0.0354 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 4.0106 0.0352 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 4.0403 0.0332 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.9468 0.0322 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.9184 0.0335 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 4.0016 0.0348 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.8945 0.0329 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 4.0557 0.0330 sec/batch
# Nearest to who: have, those, of, made, was, were, he, well,
# Nearest to known: of, the, most, and, from, to, s, in,
# Nearest to are: all, have, other, these, both, a, with, some,
# Nearest to time: seconds, before, to, quickly, he, but, became, the,
# Nearest to not: this, that, a, but, only, does, to, is,
# Nearest to in: and, the, to, a, s, from, as, with,
# Nearest to a: the, and, in, to, of, is, s, also,
# Nearest to used: also, sometimes, for, some, term, common, in, describe,
# Nearest to issue: upsetting, agreed, this, formally, oblique, issuing, favour, compromise,
# Nearest to mathematics: mathematical, mathematicians, theorems, erd, philosophische, whitehead, studies, introductions,
# Nearest to pope: papal, popes, benedict, papacy, xiii, ii, xxiii, reverie,
# Nearest to professional: wrestler, training, practitioners, moise, certification, kodokan, accountants, aia,
# Nearest to animals: animal, fauna, zoology, artificial, shinto, humans, fasciculata, science,
# Nearest to units: unit, si, metre, bipm, redefined, cgs, nist, customary,
# Nearest to engine: engines, improves, ramjet, xp, search, abrahamic, rim, turbojet,
# Nearest to taking: returning, return, syngman, harpist, philadelphia, marsalis, in, wageningen,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 4.0155 0.0364 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.9767 0.0340 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
